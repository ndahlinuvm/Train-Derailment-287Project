# %% [markdown]
# An Analysis of Train Derailments

# %% [markdown]
# Setup

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# import data
full_data = pd.read_csv("Rail_Equipment_Accident_Incident_Data.csv")
full_data.head()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (27,43,46,47,48,50,59,61,62,63,64,65,66,67,68,69,71,130,131,136) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Reporting Railroad Code           Reporting Railroad Name  Report Year  \
# 0                      NS  Norfolk Southern Railway Company       2016.0
# 1                      NS  Norfolk Southern Railway Company       2016.0
# 2                      CR                           Conrail       1981.0
# 3                      NS  Norfolk Southern Railway Company       2016.0
# 4                      NS  Norfolk Southern Railway Company       2016.0
#
#   Accident Number                                           PDF Link  \
# 0          120068  https://safetydata.fra.dot.gov/Officeofsafety/...
# 1          120068  https://safetydata.fra.dot.gov/Officeofsafety/...
# 2         0420001  https://safetydata.fra.dot.gov/Officeofsafety/...
# 3          120161  https://safetydata.fra.dot.gov/Officeofsafety/...
# 4          120161  https://safetydata.fra.dot.gov/Officeofsafety/...
#
#    Accident Year  Accident Month Other Railroad Code Other Railroad Name  \
# 0           16.0             4.0                 NaN                 NaN
# 1           16.0             4.0                 NaN                 NaN
# 2           81.0             4.0                 NaN                 NaN
# 3           16.0             4.0                 NaN                 NaN
# 4           16.0             4.0                 NaN                 NaN
#
#   Other Accident Number  ...  Other Railroad SMT Grouping  \
# 0                   NaN  ...                          NaN
# 1                   NaN  ...                          NaN
# 2                   NaN  ...                          NaN
# 3                   NaN  ...                          NaN
# 4                   NaN  ...                          NaN
#
#    Other Parent Railroad Company Code Other Parent Railroad Company Name  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
#   Other Railroad Holding Company Maintenance Railroad Company Grouping  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#    Maintenance Railroad Class  Maintenance Railroad SMT Grouping  \
# 0                     Class 1           SMT-3 - Norfolk Southern
# 1                     Class 1           SMT-3 - Norfolk Southern
# 2                     Class 3                                NaN
# 3                     Class 1           SMT-3 - Norfolk Southern
# 4                     Class 1           SMT-3 - Norfolk Southern
#
#   Maintenance Parent Railroad Company Code  \
# 0                                       NS
# 1                                       NS
# 2                                     CRSH
# 3                                       NS
# 4                                       NS
#
#    Maintenance Parent Railroad Company Name  \
# 0          Norfolk Southern Railway Company
# 1          Norfolk Southern Railway Company
# 2             Consolidated Rail Corporation
# 3          Norfolk Southern Railway Company
# 4          Norfolk Southern Railway Company
#
#   Maintenance Railroad Holding Company
# 0     Norfolk Southern Railway Company
# 1     Norfolk Southern Railway Company
# 2                         Not Assigned
# 3     Norfolk Southern Railway Company
# 4     Norfolk Southern Railway Company
#
# [5 rows x 160 columns]

# %% [markdown]
# Data Cleaning

# %%
features_to_drop = ["Reporting Railroad Code",
                 "PDF Link",
                 "Other Railroad Code",
                 "Maintenance Railroad Code",
                 "Accident Type Code",
                 "State Code",
                 "County Code",
                 "Visibility Code",
                 "Weather Condition Code",
                 "Track Type Code",
                 "Train Direction Code",
                 "Equipment Type Code",
                 "Signalization Code",
                 "Method of Operation Code",
                 "Remote Control Locomotive Code",
                 "Primary Accident Cause Code",
                 "Contributing Accident Cause Code",
                 "Accident Cause Code",
                 "Class Code",
                 "Reporting Parent Railroad Company Code",
                 "Other Parent Railroad Company Code",
                 "Maintenance Parent Railroad Company Code"
]

data = full_data.drop(features_to_drop,axis=1)
data.head()
# Out:
#             Reporting Railroad Name  Report Year Accident Number  \
# 0  Norfolk Southern Railway Company       2016.0          120068
# 1  Norfolk Southern Railway Company       2016.0          120068
# 2                           Conrail       1981.0         0420001
# 3  Norfolk Southern Railway Company       2016.0          120161
# 4  Norfolk Southern Railway Company       2016.0          120161
#
#    Accident Year  Accident Month Other Railroad Name Other Accident Number  \
# 0           16.0             4.0                 NaN                   NaN
# 1           16.0             4.0                 NaN                   NaN
# 2           81.0             4.0                 NaN                   NaN
# 3           16.0             4.0                 NaN                   NaN
# 4           16.0             4.0                 NaN                   NaN
#
#    Other Accident Year  Other Accident Month  \
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
#           Maintenance Railroad Name  ... Other Railroad Company Grouping  \
# 0  Norfolk Southern Railway Company  ...                             NaN
# 1  Norfolk Southern Railway Company  ...                             NaN
# 2                           Conrail  ...                             NaN
# 3  Norfolk Southern Railway Company  ...                             NaN
# 4  Norfolk Southern Railway Company  ...                             NaN
#
#    Other Railroad Class  Other Railroad SMT Grouping  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# 2                   NaN                          NaN
# 3                   NaN                          NaN
# 4                   NaN                          NaN
#
#   Other Parent Railroad Company Name  Other Railroad Holding Company  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#   Maintenance Railroad Company Grouping Maintenance Railroad Class  \
# 0                                   NaN                    Class 1
# 1                                   NaN                    Class 1
# 2                                   NaN                    Class 3
# 3                                   NaN                    Class 1
# 4                                   NaN                    Class 1
#
#   Maintenance Railroad SMT Grouping  Maintenance Parent Railroad Company Name  \
# 0          SMT-3 - Norfolk Southern          Norfolk Southern Railway Company
# 1          SMT-3 - Norfolk Southern          Norfolk Southern Railway Company
# 2                               NaN             Consolidated Rail Corporation
# 3          SMT-3 - Norfolk Southern          Norfolk Southern Railway Company
# 4          SMT-3 - Norfolk Southern          Norfolk Southern Railway Company
#
#    Maintenance Railroad Holding Company
# 0      Norfolk Southern Railway Company
# 1      Norfolk Southern Railway Company
# 2                          Not Assigned
# 3      Norfolk Southern Railway Company
# 4      Norfolk Southern Railway Company
#
# [5 rows x 138 columns]

# %% [markdown]
# Exploratory Analysis and Visualization
